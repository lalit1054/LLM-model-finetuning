# %% [markdown]
# # Training Notebook
#
# This notebook fine-tunes the local base model and saves the adapter separately under `models/adapters/`.

# %%
# !python ../src/train.py \
  --model_name ../models/base/Qwen3.5-0.8B \
  --train_file ../data/processed/train.jsonl \
  --validation_file ../data/processed/validation.jsonl \
  --output_dir ../models/adapters/qwen3.5-0.8b-chatdoctor-unsloth
