# %% [markdown]
# # Evaluation Notebook
#
# This notebook evaluates the unchanged base model against the separate fine-tuned adapter.

# %%
# !python ../src/evaluate.py \
  --base_model ../models/base/Qwen3.5-0.8B \
  --adapter_path ../models/adapters/qwen3.5-0.8b-chatdoctor-unsloth \
  --test_file ../data/processed/test.jsonl \
  --output_dir ../outputs/eval \
  --num_samples 100
